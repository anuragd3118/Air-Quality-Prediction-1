# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
os.getcwd()
# Out:
# 'C:\\Users\\iZfig\\OneDrive\\Desktop\\Mini_project\\DataSet'

# %%
os.chdir('C:\\Users\\iZfig\OneDrive\Desktop\Mini_project\DataSet')

# %%
df=pd.read_csv('rawd.csv',delimiter=',')
df.head()
# Out:
#    Year  Month  Day  Rain  Evap  MaxTemp  MinTemp  WindVelocity  \
# 0  2018      1    1   0.0   3.3     29.8     10.4           2.4
# 1  2018      1    2   0.0   4.0     29.6     11.4           2.1
# 2  2018      1    3   0.0   3.6     29.2     13.4           3.2
# 3  2018      1    4   0.0   3.5     28.6     10.8           3.4
# 4  2018      1    5   0.0   4.6     28.2      9.6           4.4
#
#    Solar_Radiation  Bright_Sunshine  Rel_Humidity  PM2.5
# 0             16.2              9.3            89  56.22
# 1             15.8              9.0            89  63.57
# 2             12.7              8.4            88  72.61
# 3             13.9              6.0            89  68.25
# 4             14.1              7.3            88  70.88

# %%
X= df.iloc[:,0:]
print(X)
# Out:
#      Year  Month  Day  Rain  Evap  MaxTemp  MinTemp  WindVelocity  \
# 0    2018      1    1   0.0   3.3     29.8     10.4           2.4
# 1    2018      1    2   0.0   4.0     29.6     11.4           2.1
# 2    2018      1    3   0.0   3.6     29.2     13.4           3.2
# 3    2018      1    4   0.0   3.5     28.6     10.8           3.4
# 4    2018      1    5   0.0   4.6     28.2      9.6           4.4
# 5    2018      1    6   0.0   3.7     28.8      9.0           3.1
# 6    2018      1    7   0.0   4.1     28.0     10.2           3.6
# 7    2018      1    8   0.0   4.1     29.0     10.0           4.0
# 8    2018      1    9   0.0   4.3     26.8     10.4           5.6
# 9    2018      1   10   0.0   3.6     26.2     11.6           4.5
# 10   2018      1   11   0.0   4.8     29.0     11.8           4.1
# 11   2018      1   12   0.0   3.8     31.4     12.6           2.1
# 12   2018      1   13   0.0   4.7     31.6     12.8           2.6
# ...

# %%
sns.catplot(x="Year", y="PM2.5", data=X)
plt.figure()
plt.scatter(x="Rain", y="PM2.5", data=X)
plt.show()

# %%
import seaborn as sns
sns.catplot(x="Year", y="PM2.5", data=X)
plt.figure()
plt.scatter(x="Rel_Humidity", y="PM2.5", data=X)
plt.show()

# %%
import seaborn as sns
sns.catplot(x="Year", y="PM2.5", data=X)
plt.figure()
plt.scatter(x="WindVelocity", y="PM2.5", data=X)
plt.show()
sns.catplot(x="Solar_Radiation", y="PM2.5", data=X)
plt.figure()
plt.scatter(x="Rel_Humidity", y="PM2.5", data=X)
plt.show()
plt.figure()
plt.scatter(x="Bright_Sunshine", y="PM2.5", data=X)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 597 entries, 0 to 596
# Data columns (total 12 columns):
# Year               597 non-null int64
# Month              597 non-null int64
# Day                597 non-null int64
# Rain               597 non-null float64
# Evap               597 non-null float64
# MaxTemp            597 non-null float64
# MinTemp            597 non-null float64
# WindVelocity       597 non-null float64
# Solar_Radiation    597 non-null float64
# Bright_Sunshine    597 non-null float64
# Rel_Humidity       597 non-null int64
# PM2.5              589 non-null float64
# dtypes: float64(8), int64(4)
# memory usage: 56.0 KB

# %%
df.describe()
# Out:
#               Year       Month         Day        Rain        Evap  \
# count   597.000000  597.000000  597.000000  597.000000  597.000000
# mean   2018.388610    5.685092   15.524288    1.574372    6.858124
# std       0.487843    3.210929    8.758974    6.000100    2.841688
# min    2018.000000    1.000000    1.000000    0.000000    0.600000
# 25%    2018.000000    3.000000    8.000000    0.000000    4.600000
# 50%    2018.000000    5.000000   15.000000    0.000000    6.300000
# 75%    2019.000000    8.000000   23.000000    0.000000    9.000000
# max    2019.000000   12.000000   31.000000   68.200000   14.400000
#
#           MaxTemp     MinTemp  WindVelocity  Solar_Radiation  Bright_Sunshine  \
# count  597.000000  597.000000    597.000000       597.000000       597.000000
# mean    33.501843   19.987940      7.219263        17.023786         6.916415
# std      4.405173    4.781766      4.469484         4.375684         3.207076
# ...

# %%
df.shape
# Out:
# (597, 12)

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Rain               0
# Evap               0
# MaxTemp            0
# MinTemp            0
# WindVelocity       0
# Solar_Radiation    0
# Bright_Sunshine    0
# Rel_Humidity       0
# PM2.5              8
# dtype: int64

# %%
#UniVariate Analysis

# %%
df.boxplot(column='PM2.5')

# %%
df.boxplot(column='Month')

# %%
df.boxplot(column='MaxTemp') # Outliers are present

# %%
df.boxplot(column='MinTemp') # Outliers are present

# %%
df.boxplot(column='PM2.5',by='Month')

# %%
df.boxplot(column='PM2.5',by='Day')

# %%
plt.hist(df['PM2.5'],10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([30., 86., 63., 80., 84., 55., 49., 51., 47., 44.]),
#  array([ 0.94 ,  8.724, 16.508, 24.292, 32.076, 39.86 , 47.644, 55.428,
#         63.212, 70.996, 78.78 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['MaxTemp'],10)
# Out:
# (array([  3.,   3.,  17.,  35., 162., 125.,  63.,  82.,  67.,  40.]),
#  array([19.2, 21.6, 24. , 26.4, 28.8, 31.2, 33.6, 36. , 38.4, 40.8, 43.2]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['Rel_Humidity'])
# Out:
# (array([  3.,   3.,   9.,  23.,  40.,  57.,  58., 132., 136., 136.]),
#  array([30. , 36.9, 43.8, 50.7, 57.6, 64.5, 71.4, 78.3, 85.2, 92.1, 99. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['Bright_Sunshine'],10)
# Out:
# (array([ 65.,  21.,  22.,  29.,  34.,  46.,  94., 168., 106.,  12.]),
#  array([ 0.  ,  1.18,  2.36,  3.54,  4.72,  5.9 ,  7.08,  8.26,  9.44,
#         10.62, 11.8 ]),
#  <a list of 10 Patch objects>)

# %%
df.hist('MinTemp',bins=5),df.hist('WindVelocity',bins=5)
# Out:
# (array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A239980CC0>]],
#        dtype=object),
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A23A3729E8>]],
#        dtype=object))

# %%
df.corr()
# Out:
#                      Year     Month       Day      Rain      Evap   MaxTemp  \
# Year             1.000000 -0.328775 -0.028128  0.003523  0.257210  0.252238
# Month           -0.328775  1.000000 -0.001995  0.126443 -0.333783 -0.247615
# Day             -0.028128 -0.001995  1.000000 -0.056913  0.047039  0.035354
# Rain             0.003523  0.126443 -0.056913  1.000000 -0.069900 -0.086703
# Evap             0.257210 -0.333783  0.047039 -0.069900  1.000000  0.882722
# MaxTemp          0.252238 -0.247615  0.035354 -0.086703  0.882722  1.000000
# MinTemp          0.178231  0.231401  0.027825  0.081772  0.417755  0.540066
# WindVelocity     0.171625 -0.005282 -0.094681  0.101448  0.143583  0.032386
# Solar_Radiation  0.193187 -0.360771  0.066304 -0.267790  0.762171  0.764357
# Bright_Sunshine  0.153240 -0.315428  0.067731 -0.280463  0.530213  0.500187
# Rel_Humidity    -0.061202  0.362031 -0.014791  0.181540 -0.726246 -0.669610
# ...

# %%
c = df.corr()
sns.heatmap(c,xticklabels=c.columns,yticklabels=c.columns)

# %%
#Bivariate Analysis

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ax=plt.plot(df["MaxTemp"],df["PM2.5"],'o')
plt.ylabel("PM2.5")
plt.xlabel("MaxTemp")
# Out:
# Text(0.5, 0, 'MaxTemp')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ax=plt.plot(df["Rel_Humidity"],df["PM2.5"],'o')
plt.ylabel("PM2.5")
plt.xlabel("Rel_Humidity")
# Out:
# Text(0.5, 0, 'Rel_Humidity')

# %%
#PairPlot

# %%
sns.pairplot(df)

# %%
df.groupby('Year').agg(['mean','median','max'])
# Out:
#          Month                   Day                 Rain               \
#           mean median max       mean median max      mean median   max
# Year
# 2018  6.526027      7  12  15.720548     16  31  1.557534    0.0  68.2
# 2019  4.362069      4   8  15.215517     15  31  1.600862    0.0  51.2
#
#           Evap  ... Solar_Radiation Bright_Sunshine              Rel_Humidity  \
#           mean  ...             max            mean median   max         mean
# Year            ...
# 2018  6.275890  ...            24.0        6.524932   7.70  10.9    82.180822
# 2019  7.774138  ...            24.6        7.532328   8.65  11.8    80.508621
#
#                      PM2.5
#      median max       mean  median    max
# Year
# 2018     85  99  39.744667  38.075  78.04
# 2019     84  99  34.425371  31.660  78.78
#
# [2 rows x 33 columns]

# %%
df.groupby('Month').agg(['mean','median','max'])
# Out:
#               Year                      Day                 Rain               \
#               mean  median   max       mean median max      mean median   max
# Month
# 1      2018.500000  2018.5  2019  16.000000   16.0  31  0.143548    0.0   8.7
# 2      2018.500000  2018.5  2019  14.500000   14.5  28  0.044643    0.0   2.5
# 3      2018.500000  2018.5  2019  16.000000   16.0  31  0.006452    0.0   0.4
# 4      2018.500000  2018.5  2019  15.500000   15.5  30  1.000000    0.0  27.4
# 5      2018.500000  2018.5  2019  16.000000   16.0  31  0.720968    0.0  11.6
# 6      2018.500000  2018.5  2019  15.500000   15.5  30  3.881667    0.0  68.2
# 7      2018.500000  2018.5  2019  16.000000   16.0  31  2.601613    0.0  29.6
# 8      2018.392157  2018.0  2019  13.843137   13.0  31  5.003922    0.4  47.9
# 9      2018.000000  2018.0  2018  15.500000   15.5  30  3.200000    0.0  28.0
# 10     2018.000000  2018.0  2018  16.000000   16.0  31  0.829032    0.0  23.7
# ...
